# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-Mohamed-Ibrahim/Wordle-Solver/blob/kaggle/notebooks/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# %%
# %cd ..
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/'
# /content

# %%
 # !rm -r Wordle-Solver
# Out:
# rm: cannot remove '/kaggle/working/Wordle-Solver': No such file or directory

# %%
# !git clone -b kaggle https://Mohamed-Mohamed-Ibrahim:$GITHUB_TOKEN@github.com/Mohamed-Mohamed-Ibrahim/Wordle-Solver.git
# Out:
# Cloning into 'Wordle-Solver'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 93 (delta 45), reused 71 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 221.68 KiB | 18.47 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# %cd Wordle-Solver
# Out:
# /content/Wordle-Solver

# %%
# !git log -1 --oneline
# Out:
# 9cc2f87 (HEAD -> kaggle, origin/kaggle) Adding colab notebook.

# %%
# !python main.py
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.34 µs
# ====================================================================================================
