# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-Mohamed-Ibrahim/Wordle-Solver/blob/main/notebooks/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# %%
# %cd ..
# Out:
# /content

# %%
# !rm -r Wordle-Solver

# %%
# !git clone https://Mohamed-Mohamed-Ibrahim:$GITHUB_TOKEN@github.com/Mohamed-Mohamed-Ibrahim/Wordle-Solver.git
# Out:
# Cloning into 'Wordle-Solver'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 154 (delta 84), reused 105 (delta 42), pack-reused 0 (from 0)
# Receiving objects: 100% (154/154), 233.57 KiB | 1.84 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# !cp /content/pattern_matrix.csv /content/Wordle-Solver/data/pattern_matrix.csv

# %%
# %cd Wordle-Solver
# Out:
# /content/Wordle-Solver

# %%
# !git log -1 --oneline
# Out:
# 184545f (HEAD -> main, origin/main, origin/HEAD) Adding printing statements.

# %%
# !python main.py
# Out:
# ...
#
# prior entropy H(W)=11.663
# best-guess expected feedback entropy H(Y)=5.978
# expected posterior entropy H(W|Y)=5.684
# information gain I(W;Y)=5.978
# BEST=soare
#
# ...
#
# Guess Word: soare
# Feedback (g for green, y for yellow, r for grey): rrygr
# Entropy gained from guess: 0.0
#
# prior entropy H(W)=11.663
# best-guess expected feedback entropy H(Y)=3.682
# expected posterior entropy H(W|Y)=7.981
# information gain I(W;Y)=3.682
# BEST=mincy
#
# ...
#
# Guess Word: mincy
# Feedback (g for green, y for yellow, r for grey): grrrg
# Entropy gained from guess: 7.414740862073957
#
# prior entropy H(W)=4.248
# best-guess expected feedback entropy H(Y)=0.000
# expected posterior entropy H(W|Y)=4.248
# information gain I(W;Y)=0.000
# BEST=marry
#
# ...
#
# Guess Word: marry
# Feedback (g for green, y for yellow, r for grey): ggggg
# Entropy gained from guess: 4.247927513443585
#
# Well Done
