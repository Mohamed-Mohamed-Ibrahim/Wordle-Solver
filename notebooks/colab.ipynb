# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-Mohamed-Ibrahim/Wordle-Solver/blob/kaggle/notebooks/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# %%
# %cd ..
# Out:
# /content

# %%
# !rm -r Wordle-Solver

# %%
# !git clone -b kaggle https://Mohamed-Mohamed-Ibrahim:$GITHUB_TOKEN@github.com/Mohamed-Mohamed-Ibrahim/Wordle-Solver.git
# Out:
# Cloning into 'Wordle-Solver'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 112 (delta 59), reused 79 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 227.45 KiB | 18.95 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !cp /content/pattern_matrix.csv /content/Wordle-Solver/data/pattern_matrix.csv

# %%
# %cd Wordle-Solver
# Out:
# /content/Wordle-Solver

# %%
# !git log -1 --oneline
# Out:
# 8c0bab3 (HEAD -> kaggle, origin/kaggle) Using targets instead of ref_targets.

# %%
# !python main.py
# Out:
# ...
#
# Remaining possible targets: 3242
# prior entropy H(W)=11.663
# best-guess expected feedback entropy H(Y)=5.978
# expected posterior entropy H(W|Y)=5.684
# information gain I(W;Y)=5.978
# BEST=soare
#
# ...
#
# Guess Word: Feedback (g for green, y for yellow, r for grey): rgryy
# Entropy gained from guess: 0.05412409150017595
#
# Remaining possible targets: 25
# prior entropy H(W)=11.609
# best-guess expected feedback entropy H(Y)=2.443
# expected posterior entropy H(W|Y)=9.165
# information gain I(W;Y)=2.443
# BEST=clown
#
# ...
#
# Guess Word: Feedback (g for green, y for yellow, r for grey): rryyr
# Entropy gained from guess: 0.42301699036395596
#
# Remaining possible targets: 4
# prior entropy H(W)=11.186
# best-guess expected feedback entropy H(Y)=2.000
# expected posterior entropy H(W|Y)=9.186
# information gain I(W;Y)=2.000
# BEST=compt
#
# ...
#
# Guess Word: Feedback (g for green, y for yellow, r for grey): rgryr
# Entropy gained from guess: 0.5
#
# Remaining possible targets: 1
# ...
