# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# %%
 # !rm -r /kaggle/working/Wordle-Solver
# Out:
# rm: cannot remove '/kaggle/working/Wordle-Solver': No such file or directory

# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !git clone -b kaggle https://Mohamed-Mohamed-Ibrahim:$GITHUB_TOKEN@github.com/Mohamed-Mohamed-Ibrahim/Wordle-Solver.git
# Out:
# Cloning into 'Wordle-Solver'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 32 (delta 14), reused 27 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 50.15 KiB | 4.18 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# !git log -1 --oneline
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %cd /kaggle/working/Wordle-Solver
# Out:
# /kaggle/working/Wordle-Solver

# %%
# %time
# !python main.py
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.34 µs
# ====================================================================================================
#
# Targets length: 3242
# prior entropy H(W)=11.663
# best-guess expected feedback entropy H(Y)=5.978
# expected posterior entropy H(W|Y)=5.684
# information gain I(W;Y)=5.978
# BEST=soare
#
# ====================================================================================================
#
# Guess Word: Feedback (g for green, y for yellow, r for grey): 0
#
# Targets length: 39
# prior entropy H(W)=11.663
# best-guess expected feedback entropy H(Y)=3.946
# expected posterior entropy H(W|Y)=7.717
# information gain I(W;Y)=3.946
# BEST=liman
#
# ====================================================================================================
#
# Guess Word: Feedback (g for green, y for yellow, r for grey): 0
#
# Game Over ... Better Luck next time ...
